# %%
import os
import time
import requests
import pandas as pd
from lxml import html
from concurrent.futures import ThreadPoolExecutor

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246',
         "Accept-Language": "en-US,en;q=0.5"}

# %%
movie_ids = pd.read_csv("./datasets/links.csv", dtype=str)
movie_ids = movie_ids["imdbId"].tolist()

# %%
film_dict = dict()

# %%
def scrape_movie_data(num, movie):
    if not os.path.exists(f"./movie_text_data/movie_{num}.txt"):
        full_retrieval = False
        title, director, genres, brief_plot, year, stars = None, None, None, None, None, None
        inner_dict = dict()
        condition, iter = 0, 0
        url = "https://www.imdb.com/title/tt" + str(movie) + "/"

        while full_retrieval is False and iter < 5:
            page = requests.get(url, headers=headers)

            tree = html.fromstring(page.content)

            if title == None or title == []:
                title = tree.xpath("//span[@data-testid='hero__primary-text']/text()")[0]
                if title != None and title != []:
                    inner_dict['title'] = title
                    condition += 1

            if director == None or director == []:
                director = tree.xpath("//a[@class='ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link']/text()")[0]
                if director != None and director != []:
                    inner_dict['director'] = director
                    condition += 1

            if genres == None or genres == []:
                genres = tree.xpath("//span[@class='ipc-chip__text']/text()")[:-1]
                if genres != None and genres != []:
                    inner_dict['genres'] = genres
                    condition += 1

            if brief_plot == None or brief_plot == []:
                brief_plot = tree.xpath("//span[@data-testid='plot-xs_to_m']/text()")[0]
                if brief_plot != None and brief_plot != []:
                    inner_dict['brief_plot'] = brief_plot
                    condition += 1

            if year == None or year == []:
                year = tree.xpath("//div[@class='sc-b7c53eda-0 dUpRPQ']//*/a[@class='ipc-link ipc-link--baseAlt ipc-link--inherit-color']/text()")[0]
                if year != None and year != []:
                    inner_dict['year'] = year
                    condition += 1

            if stars == None or stars == []:
                stars = tree.xpath("//div[@class='sc-b7c53eda-2 iOESUA']/div/ul[@class='ipc-metadata-list ipc-metadata-list--dividers-all title-pc-list ipc-metadata-list--baseAlt']/li[@class='ipc-metadata-list__item ipc-metadata-list-item--link'][last()]//*/a[@class='ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link']/text()")
                if stars != None and stars != []:
                    inner_dict['stars'] = stars
                    condition += 1
        
            if condition == 6:
                full_retrieval = True
                file_name = f"./movie_text_data/movie_{num}.txt"
                with open(file_name, 'w') as f:
                    f.write(f"IMDB ID -> {movie}\n")
                    f.write(f"TITLE -> {inner_dict['title']}\n")
                    f.write(f"DIRECTED BY -> {inner_dict['director']}\n")
                    f.write(f"GENRES -> {', '.join(inner_dict['genres'])}\n")
                    f.write(f"PLOT -> {inner_dict['brief_plot']}\n")
                    f.write(f"YEAR -> {inner_dict['year']}\n")
                    f.write(f"STARS -> {', '.join(inner_dict['stars'])}\n")

            time.sleep(0.25)
            iter += 1
        print(f"Number {num}, MOVIE -> {url}")

# %%
with ThreadPoolExecutor(max_workers=8) as executor:
    executor.map(scrape_movie_data, range(len(movie_ids)), movie_ids)
# Out:
# Number 151, MOVIE -> https://www.imdb.com/title/tt0112462/
# Number 139, MOVIE -> https://www.imdb.com/title/tt0115685/
# Number 2374, MOVIE -> https://www.imdb.com/title/tt0090917/
# Number 2378, MOVIE -> https://www.imdb.com/title/tt0091738/
# Number 2412, MOVIE -> https://www.imdb.com/title/tt0156901/
# Number 2457, MOVIE -> https://www.imdb.com/title/tt0144814/
# Number 2232, MOVIE -> https://www.imdb.com/title/tt0150230/
# Number 2478, MOVIE -> https://www.imdb.com/title/tt0122906/
# Number 2503, MOVIE -> https://www.imdb.com/title/tt0125659/
# Number 2521, MOVIE -> https://www.imdb.com/title/tt0037913/
# Number 2473, MOVIE -> https://www.imdb.com/title/tt0116192/
# Number 2408, MOVIE -> https://www.imdb.com/title/tt0119207/
# Number 2522, MOVIE -> https://www.imdb.com/title/tt0087799/
# Number 2543, MOVIE -> https://www.imdb.com/title/tt0053085/
# Number 2428, MOVIE -> https://www.imdb.com/title/tt0051744/
# Number 2579, MOVIE -> https://www.imdb.com/title/tt0125439/
# Number 2561, MOVIE -> https://www.imdb.com/title/tt0036376/
# Number 2504, MOVIE -> https://www.imdb.com/title/tt0188996/
# Number 2439, MOVIE -> https://www.imdb.com/title/tt0065462/
# Number 2609, MOVIE -> https://www.imdb.com/title/tt0120891/
# Number 2770, MOVIE -> https://www.imdb.com/title/tt0080491/
# Number 2795, MOVIE -> https://www.imdb.com/title/tt0168172/
# Number 2587, MOVIE -> https://www.imdb.com/title/tt0124555/
# Number 2713, MOVIE -> https://www.imdb.com/title/tt0130121/
# Number 2822, MOVIE -> https://www.imdb.com/title/tt0143746/
# Number 2677, MOVIE -> https://www.imdb.com/title/tt0138946/
# Number 2878, MOVIE -> https://www.imdb.com/title/tt0083946/
# Number 2616, MOVIE -> https://www.imdb.com/title/tt0137439/
# Number 2963, MOVIE -> https://www.imdb.com/title/tt0160620/
# Number 2911, MOVIE -> https://www.imdb.com/title/tt0170705/
# Number 3120, MOVIE -> https://www.imdb.com/title/tt0106364/
# Number 2907, MOVIE -> https://www.imdb.com/title/tt0154827/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 with ThreadPoolExecutor(max_workers=8) as executor:
#       2     executor.map(scrape_movie_data, range(len(movie_ids)), movie_ids)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
# Number 3087, MOVIE -> https://www.imdb.com/title/tt0196857/
# Number 2843, MOVIE -> https://www.imdb.com/title/tt0033804/
# Number 3078, MOVIE -> https://www.imdb.com/title/tt0053226/
# Number 3136, MOVIE -> https://www.imdb.com/title/tt0044364/
# Number 3242, MOVIE -> https://www.imdb.com/title/tt0047127/
# Number 3114, MOVIE -> https://www.imdb.com/title/tt0045162/
# Number 3237, MOVIE -> https://www.imdb.com/title/tt0055471/
# Number 3073, MOVIE -> https://www.imdb.com/title/tt0096978/
# Number 3101, MOVIE -> https://www.imdb.com/title/tt0070903/
# Number 3384, MOVIE -> https://www.imdb.com/title/tt0146882/
# Number 3449, MOVIE -> https://www.imdb.com/title/tt0051383/

# %%
film_dict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 film_dict()
#
# NameError: name 'film_dict' is not defined
